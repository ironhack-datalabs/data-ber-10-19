# %% [markdown]
# # Bike Sharing Network
#
# (Title of our awesome project, created by Niki, Georgios and Lena)

# %%
# first importing neccessary packages

import pandas as pd
import requests
import json
import matplotlib
# %matplotlib inline
from pandas.io.json import json_normalize

# import folium package for mapping:

import folium

# %% [markdown]
# ### Import API dataset

# %%
url = "http://api.citybik.es/v2/networks"
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
df = pd.DataFrame(r.json()['networks'])

# %% [markdown]
# ### Examine API dataset

# %%
df.head()
# Out:
#                           company                          href  \
# 0                [ЗАО «СитиБайк»]  /v2/networks/velobike-moscow
# 1                    [Gobike A/S]         /v2/networks/bycyklen
# 2                    [Gobike A/S]       /v2/networks/nu-connect
# 3  [Urban Infrastructure Partner]  /v2/networks/baerum-bysykkel
# 4                    [Gobike A/S]       /v2/networks/bysykkelen
#
#                 id                                           location  \
# 0  velobike-moscow  {'city': 'Moscow', 'country': 'RU', 'latitude'...
# 1         bycyklen  {'city': 'Copenhagen', 'country': 'DK', 'latit...
# 2       nu-connect  {'city': 'Utrecht', 'country': 'NL', 'latitude...
# 3  baerum-bysykkel  {'city': 'Bærum', 'country': 'NO', 'latitude':...
# 4       bysykkelen  {'city': 'Stavanger', 'country': 'NO', 'latitu...
#
#          name source license gbfs_href
# 0    Velobike    NaN     NaN       NaN
# 1    Bycyklen    NaN     NaN       NaN
# 2  Nu-Connect    NaN     NaN       NaN
# 3    Bysykkel    NaN     NaN       NaN
# 4  Bysykkelen    NaN     NaN       NaN

# %%
df.shape
# Out:
# (644, 8)

# %% [markdown]
# ### Clean dataset

# %%
# Unnest the 'location' column

df2 = json_normalize(df['location'])
df3 = df.merge(df2, left_index=True, right_index=True)

# Rename and lower the 'country' column to be in accordance with the other dataset

df3 = df3.rename(columns = {"country": "Country", 
                            "city": "City",
                            "latitude": "Latitude",
                            "longitude": "Longitude"})
df3["Country"] = pd.Series(df3.Country).str.lower()

# Drop columns which contain only NaN's or unnecessary values for our investigation

df_final = df3.drop(['location','source','license','gbfs_href'],axis=1)

# %% [markdown]
# ### Cleaned API dataframe

# %%
df_final.head()
# Out:
#                           company                          href  \
# 0                [ЗАО «СитиБайк»]  /v2/networks/velobike-moscow
# 1                    [Gobike A/S]         /v2/networks/bycyklen
# 2                    [Gobike A/S]       /v2/networks/nu-connect
# 3  [Urban Infrastructure Partner]  /v2/networks/baerum-bysykkel
# 4                    [Gobike A/S]       /v2/networks/bysykkelen
#
#                 id        name        City Country   Latitude  Longitude
# 0  velobike-moscow    Velobike      Moscow      ru  55.750000  37.616667
# 1         bycyklen    Bycyklen  Copenhagen      dk  55.673582  12.564984
# 2       nu-connect  Nu-Connect     Utrecht      nl  52.117000   5.067000
# 3  baerum-bysykkel    Bysykkel       Bærum      no  59.894550  10.546343
# 4       bysykkelen  Bysykkelen   Stavanger      no  58.969975   5.733107

# %% [markdown]
# ### Import csv dataset from open source

# %%
import pandas as pd

df4 = pd.read_csv("worldcitiespop.csv", low_memory=False)

# %% [markdown]
# ### Examine csv dataframe

# %%
df4.head()
# Out:
#   Country        City  AccentCity Region  Population   Latitude  Longitude
# 0      ad       aixas       Aixàs     06         NaN  42.483333   1.466667
# 1      ad  aixirivali  Aixirivali     06         NaN  42.466667   1.500000
# 2      ad  aixirivall  Aixirivall     06         NaN  42.466667   1.500000
# 3      ad   aixirvall   Aixirvall     06         NaN  42.466667   1.500000
# 4      ad    aixovall    Aixovall     06         NaN  42.466667   1.483333

# %%
df4.shape
# Out:
# (3173958, 7)

# %% [markdown]
# ### Clean csv dataframe

# %%
# Dropping irrelevant and na values
df5 = df4.drop(columns=["City", "Region"]).dropna()
df6 = df5.rename(columns={"AccentCity": "City"})

# Remove duplicates and reseting index
df7 = df6.drop_duplicates()
df2_final = df7.reset_index(drop=True)

# %% [markdown]
# ### Cleaned csv dataframe

# %%
df2_final.head()
# Out:
#   Country              City  Population   Latitude  Longitude
# 0      ad  Andorra la Vella     20430.0  42.500000   1.516667
# 1      ad           Canillo      3292.0  42.566667   1.600000
# 2      ad            Encamp     11224.0  42.533333   1.583333
# 3      ad        La Massana      7211.0  42.550000   1.516667
# 4      ad      Les Escaldes     15854.0  42.500000   1.533333

# %% [markdown]
# ### Merge two datasets

# %%
ultimate_df = df_final.merge(df2_final, left_on=['City', 'Country'], 
                                      right_on=['City', 'Country'], how='left')

# %% [markdown]
# ### Clean ultimate dataframe

# %%
ultimate_df = ultimate_df.rename(columns={'Latitude_y': 'City Latitude',
                                    'Longitude_y': 'City Longitude',    
                                    'Latitude_x': 'Company Latitude',
                                    'Longitude_x': 'Company Longitude',
                                    'company': 'Company',
                                    'name': 'Name'})

# %%
# Remove two rows that were duplicates

ultimate_df.drop([600, 603], inplace=True)

# %%
# Check if the duplicate 'City' values have actual differeces in other columns

ultimate_df[ultimate_df["City"]=="London"]
# Out:
#                      Company                           href                id  \
# 74   [PBSC, Serco Group plc]  /v2/networks/santander-cycles  santander-cycles
# 493          [Nextbike GmbH]   /v2/networks/nextbike-london   nextbike-london
#
#                  Name    City Country  Company Latitude  Company Longitude  \
# 74   Santander Cycles  London      gb         51.511214          -0.119824
# 493          Nextbike  London      gb         51.486200          -0.119660
#
#      Population  City Latitude  City Longitude
# 74    7421228.0      51.514125       -0.093689
# 493   7421228.0      51.514125       -0.093689

# %%
# Reset index of the final dataframe

ultimate_df.reset_index(drop=True)
# Out:
#                             Company                                      href  \
# 0                  [ЗАО «СитиБайк»]              /v2/networks/velobike-moscow
# 1                      [Gobike A/S]                     /v2/networks/bycyklen
# 2                      [Gobike A/S]                   /v2/networks/nu-connect
# 3    [Urban Infrastructure Partner]              /v2/networks/baerum-bysykkel
# 4                      [Gobike A/S]                   /v2/networks/bysykkelen
# ..                              ...                                       ...
# 639                 [Nextbike GmbH]  /v2/networks/rowerowe-lodzkie-rl-lodz-rl
# 640                 [Nextbike GmbH]               /v2/networks/nextbike-odesa
# 641                 [Nextbike GmbH]              /v2/networks/nextbike-alvsjo
# 642                 [Nextbike GmbH]         /v2/networks/nextbike-wittenberge
# 643                 [Nextbike GmbH]               /v2/networks/frelo-freiburg
#
#                               id              Name         City Country  \
# 0                velobike-moscow          Velobike       Moscow      ru
# 1                       bycyklen          Bycyklen   Copenhagen      dk
# 2                     nu-connect        Nu-Connect      Utrecht      nl
# 3                baerum-bysykkel          Bysykkel        Bærum      no
# 4                     bysykkelen        Bysykkelen    Stavanger      no
# ..                           ...               ...          ...     ...
# 639  rowerowe-lodzkie-rl-lodz-rl  Rowerowe Łódzkie         Łódź      pl
# 640               nextbike-odesa          Nextbike        Odesa      ua
# 641              nextbike-alvsjo          Nextbike       Älvsjö      de
# 642         nextbike-wittenberge          Nextbike  Wittenberge      de
# 643               frelo-freiburg             Frelo     Freiburg      de
#
#      Company Latitude  Company Longitude  Population  City Latitude  \
# 0           55.750000          37.616667  10381288.0      55.752222
# 1           55.673582          12.564984   1089958.0      55.666667
# 2           52.117000           5.067000    267044.0      52.093813
# 3           59.894550          10.546343         NaN            NaN
# 4           58.969975           5.733107    173535.0      58.966667
# ..                ...                ...         ...            ...
# 639         51.767400          19.457500         NaN            NaN
# 640         46.467200          30.716400   1001553.0      46.463934
# 641         59.274500          18.005000         NaN            NaN
# 642         52.995200          11.751700     20322.0      53.000000
# 643         47.995800           7.844530    213920.0      48.000000
#
#      City Longitude
# 0         37.615556
# 1         12.583333
# 2          5.119095
# 3               NaN
# 4          5.750000
# ..              ...
# 639             NaN
# 640       30.738551
# 641             NaN
# 642       11.750000
# 643        7.850000
#
# [644 rows x 11 columns]

# %% [markdown]
# ### Visualization in plots

# %%
# Check the 5 most famous bike sharing companies and plot them

ultimate_df.Company.value_counts()[:5]
ultimate_df.Company.value_counts()[:5].plot(kind='bar');

# %%
# Find the most populated cities worldwide and plot them

top_city_population= ultimate_df[["Population","City"]].sort_values("Population",ascending= False).head(25)
top_city_population.drop_duplicates().plot(x="City", kind='bar');

# %%
# Find the 20 most populated cities worldwide and the bike sharing companies located there

top_city_population2 = ultimate_df[["Population","Company", "City"]].sort_values("Population",ascending= False).head(20)

# %%
top_city_population2
# Out:
#      Population                                            Company  \
# 605  10928270.0                                    [Nextbike GmbH]
# 0    10381288.0                                   [ЗАО «СитиБайк»]
# 193  10021437.0                    [Tembici, PBSC Urban Solutions]
# 121  10021437.0                                          [PegBike]
# 278   9797536.0                        [Baksi Bike Sharing System]
# 493   7421228.0                                    [Nextbike GmbH]
# 74    7421228.0                            [PBSC, Serco Group plc]
# 194   6023742.0                    [Tembici, PBSC Urban Solutions]
# 69    5104475.0                               [BTS Group Holdings]
# 201   4837248.0                    [Tembici, PBSC Urban Solutions]
# 199   3730212.0                    [PBSC, Alta Bicycle Share, Inc]
# 517   3598199.0                                    [Nextbike GmbH]
# 514   3398362.0                                    [Nextbike GmbH]
# 98    3102644.0   Empresa Municipal de Transportes de Madrid, S.A.
# 195   2711903.0                    [Tembici, PBSC Urban Solutions]
# 276   2501895.0                        [Baksi Bike Sharing System]
# 312   2416920.0  [Mobilicidade Tecnologia LTD, Grupo Serttel LTDA]
# 305   2373255.0  [Mobilicidade Tecnologia LTD, Grupo Serttel LTDA]
# 309   2207812.0  [Mobilicidade Tecnologia LTD, Grupo Serttel LTDA]
# 82    2110694.0                                         [Smovengo]
#
#                City
# 605           Delhi
# 0            Moscow
# 193       São Paulo
# 121       São Paulo
# 278        Istanbul
# 493          London
# 74           London
# 194  Rio de Janeiro
# 69          Bangkok
# 201        Santiago
# 199       Melbourne
# 517       Hyderabad
# 514          Berlin
# 98           Madrid
# 195        Salvador
# 276           Izmir
# 312       Fortaleza
# 305  Belo Horizonte
# 309        Brasília
# 82            Paris

# %% [markdown]
# ### Create function for fun

# %%
# This little extra is a function that based on the city input returns the companies that have bike sharing functions in the
# city

def findcompany(city):
    return ultimate_df[ultimate_df["City"]==city]["Company"]

# %%
# Test the function

findcompany("London")
# Out:
# 74     [PBSC, Serco Group plc]
# 493            [Nextbike GmbH]
# Name: Company, dtype: object

# %% [markdown]
# ### Export merged csv file

# %%
final_csv = ultimate_df.to_csv('final_dataset.csv', sep=',', index=False)

# %% [markdown]
# ### Visualization as map

# %%
# Import csv file
# this is our exported merged csv file which is reassigned to 'merged':

merged = pd.read_csv('merged_df.csv')

# %%
# create dict to extract 'Company', 'Latitude', 'Longitude' for mapping:

company_values=list(merged['Name'])

latitude_values=list(merged['Latitude'])

longitude_values=list(merged['Longitude'])


dict_to_map={'Longitude':longitude_values,
             'Latitude':latitude_values,
             'Company':company_values}

# %%
# create empty map:

world_map = folium.Map(location=[0, 0], zoom_start=2)


# create Data Frame to assign latitude, Logitude and Company to it:

data = pd.DataFrame(dict_to_map)

longitude = list(dict_to_map['Longitude'])
latitude = list(dict_to_map['Latitude'])
company = list()

# add marker to map to show companys worldwide:

for i in range(len(data)):
    folium.Marker((latitude[i], longitude[i]), popup = data.iloc[i]['Company']).add_to(world_map)
    
world_map.save('world_map.html')


# display map with interactive marker for each bike shop of the bike companies

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
