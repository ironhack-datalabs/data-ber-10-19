# %%
x = 'Happy'
y = 'Puppies'
z = [x,y]

a = ' Happy Puppies'
print('Happy P' in a)
# Out:
# True

# %%
print(x.split('p'))
# Out:
# ['Ha', '', 'y']

# %%
print(a)
print(a.strip())
# Out:
#  Happy Puppies
# Happy Puppies
